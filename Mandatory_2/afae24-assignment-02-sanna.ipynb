# %% [markdown]
# # Algorithmic Fairness, Accountability, and Ethics, Spring 2024
#
# ## Mandatory Assignment 2
#
# Please use the following code to prepare the dataset.

# %%
from folktables.acs import adult_filter
from folktables import ACSDataSource, BasicProblem, generate_categories
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split, KFold, cross_val_score
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import balanced_accuracy_score, accuracy_score,f1_score
from sklearn.preprocessing import StandardScaler
from sklearn.pipeline import make_pipeline
import matplotlib.pyplot as plt
from scipy.stats import  pearsonr
import scipy
import seaborn as sns

DOWNLOAD = False

data_source = ACSDataSource(survey_year='2018', horizon='1-Year', survey='person')
acs_data = data_source.get_data(states=["CA"], download=DOWNLOAD)


def adult_filter(data):
    """Mimic the filters in place for Adult data.
    Adult documentation notes: Extraction was done by Barry Becker from
    the 1994 Census database. A set of reasonably clean records was extracted
    using the following conditions:
    ((AAGE>16) && (AGI>100) && (AFNLWGT>1)&& (HRSWK>0))
    """
    df = data
    df = df[df['AGEP'] > 16]
    df = df[df['PINCP'] > 100]
    df = df[df['WKHP'] > 0]
    df = df[df['PWGTP'] >= 1]
    df = df[df["RAC1P"] < 3] ## keep only Whites and African-Americans
    return df


ACSIncomeNew = BasicProblem(
    features=[
        'AGEP',
        'COW',
        'SCHL',
        'MAR',
        'RELP',
        'WKHP',
        'PWGTP',
        'SEX',
        'RAC1P',
    ],
    target='PINCP',
    target_transform=lambda x: x > 25000,    
    group=['SEX', 'RAC1P'],
    preprocess=adult_filter,
    postprocess=lambda x: np.nan_to_num(x, -1),
)

definition_df = data_source.get_definitions(download=DOWNLOAD)
categories = generate_categories(features=ACSIncomeNew.features, definition_df=definition_df)
features, labels, groups = ACSIncomeNew.df_to_pandas(acs_data, categories=categories, dummies=True)

# Drop the "redundant" columns
features = features.drop(["RAC1P_White alone", 
                          "SEX_Male", 
                          "SCHL_1 or more years of college credit, no degree",  
                          "MAR_Divorced", 
                          "RELP_Adopted son or daughter",
                          'COW_Working without pay in family business or farm' ], axis = 1) 

print("Columns with the protected features:")
for i, f in enumerate(features.columns):
    if ("RAC1P" in f) or ("SEX" in f):
        print("Column ID: %s" %i, "(%s)"%f)
        
features.head()
# Out:
# Columns with the protected features:
# Column ID: 54 (SEX_Female)
# Column ID: 55 (RAC1P_Black or African American alone)
#   AGEP  WKHP PWGTP  \
# 0   21  20.0    52
# 1   65   8.0    33
# 2   33  40.0    53
# 3   18  18.0   106
# 4   27  50.0    23
#
#   COW_Employee of a private for-profit company or business, or of an individual, for wages, salary, or commissions  \
# 0                                              False
# 1                                              False
# 2                                               True
# 3                                              False
# 4                                              False
#
#   COW_Employee of a private not-for-profit, tax-exempt, or charitable organization  \
# 0                                              False
# 1                                               True
# 2                                              False
# 3                                               True
# 4                                              False
#
#   COW_Federal government employee  \
# 0                           False
# 1                           False
# 2                           False
# 3                           False
# 4                            True
#
#   COW_Local government employee (city, county, etc.)  \
# 0                                              False
# 1                                              False
# 2                                              False
# 3                                              False
# 4                                              False
#
#   COW_Self-employed in own incorporated business, professional practice or farm  \
# 0                                              False
# 1                                              False
# 2                                              False
# 3                                              False
# 4                                              False
#
#   COW_Self-employed in own not incorporated business, professional practice, or farm  \
# 0                                              False
# 1                                              False
# 2                                              False
# 3                                              False
# 4                                              False
#
#   COW_State government employee  ... RELP_Other nonrelative  \
# 0                          True  ...                  False
# 1                         False  ...                  False
# 2                         False  ...                  False
# 3                         False  ...                  False
# 4                         False  ...                  False
#
#   RELP_Other relative RELP_Parent-in-law RELP_Reference person  \
# 0               False              False                 False
# 1               False              False                 False
# 2               False              False                 False
# 3               False              False                 False
# 4               False              False                 False
#
#   RELP_Roomer or boarder RELP_Son-in-law or daughter-in-law  \
# 0                  False                              False
# 1                  False                              False
# 2                  False                              False
# 3                  False                              False
# 4                  False                              False
#
#   RELP_Stepson or stepdaughter RELP_Unmarried partner SEX_Female  \
# 0                        False                  False      False
# 1                        False                  False      False
# 2                        False                  False      False
# 3                        False                  False       True
# 4                        False                  False      False
#
#   RAC1P_Black or African American alone
# 0                                 False
# 1                                 False
# 2                                 False
# 3                                 False
# 4                                 False
#
# [5 rows x 56 columns]

# %% [markdown]
# ## The Task:
# Train three binary classifiers to predict income (label = True if income>$25k, otherwise label = False)

# %% [markdown]
# 1. Train one classification model on the raw dataset and calculate its general
# accuracy, and respectively the accuracies for men and women and for
# different races. The model does not need to be fancy, logistic regression
# or Random Forest are completely fine choices. Remember to evaluate the
# model using cross validation.

# %%
seed = 42

# %%
# Split dataset into train and test sets
X_train, X_test, y_train, y_test, group_train, group_test = train_test_split(
    features, labels, groups, test_size=0.3, random_state=seed, shuffle=True)

# Subsample for efficiency
N = 20000  # Subsample size

np.random.seed(seed)

# Generate random unique indices for subsampling
indices_train = np.random.choice(X_train.shape[0], N, replace=False)
indices_test = np.random.choice(X_test.shape[0], N, replace=False)

# Subsample using the random indices
### Train set
X_train = X_train.iloc[indices_train]
y_train = y_train.iloc[indices_train]
group_train = group_train.iloc[indices_train]
### Test set
X_test = X_test.iloc[indices_test]
y_test = y_test.iloc[indices_test]
group_test = group_test.iloc[indices_test]
group_test_dict = {
    'Males': group_test['SEX'] == 1,
    'Females': group_test['SEX'] == 2,
    'Whites': group_test['RAC1P'] == 1,
    'African-Americans': group_test['RAC1P'] == 2
}

# %%
# Subset for protected and non-protected features
X_train_p = X_train.iloc[:, -2:]
X_test_p = X_test.iloc[:, -2:]
X_train_np = X_train.iloc[:, :-2]
X_test_np = X_test.iloc[:, :-2]

## Should we train on the non-protected features only? Then group differences must be due to the correllations

# %%
def cross_acc(X, n=10):
    ''' Input:  X: training data
                n: number of folds for cross validation
        Output: results: list of cross val scores
                pipe: corresponding pipeline scaler and log regression  '''
    scaler = StandardScaler() ## We need to scale within the cross val step to avoid data leakage
    cls = LogisticRegression(penalty=None, max_iter=1000, random_state=seed)

    pipe = make_pipeline(scaler, cls)

    kfold = KFold(n, shuffle=True, random_state=seed)
    results = cross_val_score(pipe, X, np.array(y_train.astype('float')).ravel(), cv=kfold)

    ##cross-val 
    return results,pipe

# %%
results, pipe = cross_acc(X_train_np)

##cross-val 
print(results)

pd.DataFrame(results, columns=['results']).describe() ##Mean and Median similar.
# Out:
# [0.82   0.818  0.817  0.817  0.811  0.813  0.818  0.8105 0.816  0.821 ]
#          results
# count  10.000000
# mean    0.816150
# std     0.003575
# min     0.810500
# 25%     0.813750
# 50%     0.817000
# 75%     0.818000
# max     0.821000

# %%
pipe.fit(X_train_np, np.array(y_train.astype('float')).ravel())
y_hat = pipe.predict(X_test_np)

# %%
acc = list([accuracy_score(y_test, y_hat)])
# Calculate and print F1 Scores for each group
for group, group_idxs in group_test_dict.items():

    acc.append(accuracy_score(y_test[group_idxs], y_hat[group_idxs]))


df = pd.DataFrame(np.array([acc]).reshape(1, -1),
                        columns= ['overall', 'males','females','white','african_american'], 
                        index=['base_accuracy'])

df
# Out:
#                overall     males  females     white  african_american
# base_accuracy   0.8163  0.833412    0.797  0.817576          0.799431

# %% [markdown]
# 2. Using the “fairer” (reprojected) versions of the dataset, build two classification models (see more below) and calculate:
# + a) their overall accuracy,
# + b) their accuracies split for men and women, and
# + c) their accuracies split for different races. Subtasks:
#
# - Build one classification model trained on data reprojected using the
# de-correlation method from the paper “A Geometric Solution to Fair
# Representations”. Record your results and create a plot of how
# accuracies vary as functions of 𝜆Î[0,1].
#
# - Build one classification model using reprojected data from FairPCA.

# %%
from sklearn.preprocessing import FunctionTransformer

def debias_features(X, l=0):
    '''from exercises. Debias using de-correllation'''
    X = pd.DataFrame(X)

    X_p = X.iloc[:, -2:]
    X_np = X.iloc[:, :-2]

    assert X_np.shape[0]==X_p.shape[0]

    orthbasis = scipy.linalg.orth(X_p)
    
    # Debias nonprotected features
    X_np_debiased = X_np.reset_index(drop=True) - orthbasis @ orthbasis.T @ X_np

    # Return debiased nonprotected features
    return X_np_debiased + l * (X_np.reset_index(drop=True) - X_np_debiased)

def cross_acc_debias(X, n=10, l=0):
    ''' Input:  X: training data
                n: number of folds for cross validation
        Output: results: list of cross val scores
                pipe: corresponding pipeline scaler and log regression  '''
    scaler = StandardScaler() ## We need to scale within the cross val step to avoid data leakage
    transformer = FunctionTransformer(debias_features, kw_args={'l': l})
    cls = LogisticRegression(penalty=None, max_iter=1000, random_state=seed)

    pipe = make_pipeline(scaler,transformer,cls)

    kfold = KFold(n, shuffle=True, random_state=seed)
    results = cross_val_score(pipe, X, np.array(y_train.astype('float')).ravel(), cv=kfold)

    return results,pipe

# %%
X_train_np_debiased = debias_features(X_train.astype('float'))
#X_train_debiased = np.concatenate([X_train_np_debiased, X_train_p], axis=1)

# %%
results_de, pipe_de = cross_acc_debias(X_train)

# %%
pd.DataFrame(results_de, columns=['results']).describe()
# Out:
#          results
# count  10.000000
# mean    0.808950
# std     0.009734
# min     0.784500
# 25%     0.806375
# 50%     0.811500
# 75%     0.814625
# max     0.818000

# %%
pipe_de.fit(X_train_np_debiased, np.array(y_train.astype('float')).ravel())
y_hat = pipe_de.predict(X_test_np)

acc = list([accuracy_score(y_test, y_hat)])

for group, group_idxs in group_test_dict.items():

    acc.append(accuracy_score(y_test[group_idxs], y_hat[group_idxs]))

df2 = pd.DataFrame(np.array([acc]).reshape(1, -1),
                        columns= ['overall', 'males','females','white','african_american'], 
                        index=['debi_accuracy'])

df = pd.concat([df, df2])

df
# Out:
#                overall     males   females     white  african_american
# base_accuracy   0.8163  0.833412  0.797000  0.817576          0.799431
# debi_accuracy   0.8075  0.831714  0.780189  0.809508          0.780939

# %%
accs = df.loc[['base_accuracy', 'debi_accuracy']].T

_, ax = plt.subplots(1,1, figsize=(5,5))
ax.plot(accs, 'o', ms=10)
ax.legend(['base', 'debiased']);

# %%
res = []
xx = np.arange(0,1, 0.1)
df3 = pd.DataFrame(columns= ['overall', 'males','females','white','african_american'])

for i in xx:
    
    r, p = cross_acc_debias(X_train, l=i)
    res.append(np.mean(r))

    p.fit(X_train_np_debiased, np.array(y_train.astype('float')).ravel())
    y_hat = p.predict(X_test_np)

    acc = list([accuracy_score(y_test, y_hat)])

    for group, group_idxs in group_test_dict.items():
        acc.append(accuracy_score(y_test[group_idxs], y_hat[group_idxs]))

    df2 = pd.DataFrame(np.array([acc]).reshape(1, -1),
                            columns= ['overall', 'males','females','white','african_american'], 
                            index=[f'accuracy_{i:.1f}'])

    df3 = pd.concat([df3, df2])
    print(f'{i} done')

df3
# Out:
# /tmp/ipykernel_442/178862511.py:22: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   df3 = pd.concat([df3, df2])
#               overall     males   females     white  african_american
# accuracy_0.0  0.80750  0.831714  0.780189  0.809508          0.780939
# accuracy_0.1  0.80800  0.832374  0.780509  0.810208          0.778805
# accuracy_0.2  0.80745  0.831620  0.780189  0.809670          0.778094
# accuracy_0.3  0.80790  0.832091  0.780615  0.810100          0.778805
# accuracy_0.4  0.80790  0.832469  0.780189  0.810154          0.778094
# accuracy_0.5  0.80835  0.833035  0.780509  0.810476          0.780228
# accuracy_0.6  0.80860  0.833129  0.780934  0.810745          0.780228
# accuracy_0.7  0.80880  0.833506  0.780934  0.810961          0.780228
# accuracy_0.8  0.80875  0.833223  0.781147  0.810907          0.780228
# accuracy_0.9  0.80880  0.833223  0.781253  0.810907          0.780939

# %%
# Out:
# accuracy_0.0    0.80750
# accuracy_0.1    0.80800
# accuracy_0.2    0.80745
# accuracy_0.3    0.80790
# accuracy_0.4    0.80790
# accuracy_0.5    0.80835
# accuracy_0.6    0.80860
# accuracy_0.7    0.80880
# accuracy_0.8    0.80875
# accuracy_0.9    0.80880
# Name: overall, dtype: float64

# %%
plt.plot(xx,res, '.', label='average cross-val accuracy')
plt.plot(xx, df3['overall'],'.', label='debiased average accuracy on test set')
plt.xlabel('lambda value')
plt.ylabel('avg cross_val accuracy')
plt.hlines(y=df.loc['base_accuracy', 'overall'], xmin=0, xmax=1, label='base accuracy on test set')
plt.legend(bbox_to_anchor=(1,1));

## I really don't like this. There shouldn't be such a marked systematic change from the cross-val accuracy to the test set accuracy??

# %%
accs.base_accuracy
# Out:
# overall             0.816300
# males               0.833412
# females             0.797000
# white               0.817576
# african_american    0.799431
# Name: base_accuracy, dtype: float64

# %%
locs = [i for i in df3.index if 'accuracy' in i]

accs2 = df3.loc[locs].T

_, ax = plt.subplots(1,1, figsize=(5,5))
ax.plot(accs.base_accuracy, 'r*', ms=8)
ax.plot(accs2, '.', ms=10)

ax.legend(['base'] + list(xx.round(1)), bbox_to_anchor=(1,1));
